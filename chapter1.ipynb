# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 4.10.0

# %%
img= cv2.imread('imgs/pizza.jpg')
img
# Out:
# array([[[234, 232, 231],
#         [234, 232, 231],
#         [235, 233, 232],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        [[234, 232, 231],
#         [234, 232, 231],
#         [235, 233, 232],
#         ...,
#         [214, 214, 214],
#         [214, 214, 214],
#         [214, 214, 214]],
#
#        [[234, 232, 231],
#         [234, 232, 231],
#         [235, 233, 232],
#         ...,
#         [214, 214, 214],
#         [214, 214, 214],
#         [214, 214, 214]],
#
#        ...,
#
#        [[223, 221, 220],
#         [224, 222, 221],
#         [224, 222, 221],
#         ...,
#         [217, 213, 212],
#         [217, 213, 212],
#         [217, 213, 212]],
#
#        [[224, 222, 221],
#         [223, 221, 220],
#         [223, 221, 220],
#         ...,
#         [217, 213, 212],
#         [217, 213, 212],
#         [217, 213, 212]],
#
#        [[224, 222, 221],
#         [223, 221, 220],
#         [222, 220, 219],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
np.min(img)
# Out:
# np.uint8(0)

# %%
np.max(img)
# Out:
# np.uint8(255)

# %%
img.shape
# Out:
# (512, 683, 3)

# %%
cv2.imshow('image', img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(4,3))
plt.imshow(img[:,:,::-1])
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(682.5), np.float64(511.5), np.float64(-0.5))

# %%
b= img[...,0]
g=img[...,1]
r=img[...,2]
rgb= np.stack((r, g, b), axis=2)
plt.imshow(rgb)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(682.5), np.float64(511.5), np.float64(-0.5))

# %%
rgb= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(682.5), np.float64(511.5), np.float64(-0.5))

# %%
b= img[...,0]
g=img[...,1]
r=img[...,2]
print(b.shape)
plt.imshow(b)
plt.axis('off')
# Out:
# (512, 683)
# (np.float64(-0.5), np.float64(682.5), np.float64(511.5), np.float64(-0.5))

# %%
b= img[...,0]
g=img[...,1]
r=img[...,2]
print(b.shape)
plt.imshow(b, cmap='gray')
plt.axis('off')
# Out:
# (512, 683)
# (np.float64(-0.5), np.float64(682.5), np.float64(511.5), np.float64(-0.5))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img_bgr = cv2.imread('imgs/pizza.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

r = img_rgb[..., 0]
g = img_rgb[..., 1]
b = img_rgb[..., 2]

gray_real = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)

plt.figure(figsize=(12,8))

plt.subplot(231);plt.imshow(img_rgb);plt.title("Original RGB");plt.axis('off')
plt.subplot(232);plt.imshow(r, cmap='gray');plt.title("Red Channel");plt.axis('off')
plt.subplot(233);plt.imshow(g, cmap='gray');plt.title("Green Channel");plt.axis('off')
plt.subplot(234);plt.imshow(b, cmap='gray');plt.title("Blue Channel");plt.axis('off')
plt.subplot(235);plt.imshow(gray_real, cmap='gray');plt.title("True Grayscale");plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_bgr = cv2.imread('imgs/pizza.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

R = img_rgb[..., 0].astype(np.float32)
G = img_rgb[..., 1].astype(np.float32)
B = img_rgb[..., 2].astype(np.float32)

gray_manual = 0.299 * R + 0.587 * G + 0.114 * B
gray_manual = np.clip(gray_manual, 0, 255).astype(np.uint8)
gray_cv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)


plt.figure(figsize=(10,5))
plt.subplot(121);plt.imshow(gray_manual, cmap='gray');plt.title("Manual Gray (Formula)");plt.axis('off')
plt.subplot(122);plt.imshow(gray_cv, cmap='gray');plt.title("OpenCV Gray");plt.axis('off')
plt.show()

# %%
diff = np.abs(gray_manual.astype(int) - gray_cv.astype(int))
print("Max difference:", diff.max())
# Out:
# Max difference: 1
