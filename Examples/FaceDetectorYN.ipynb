# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img= cv2.imread('../imgs/peops.jpg')

plt.imshow(img[...,::-1])

# %%
model=cv2.FaceDetectorYN_create(r"D:\Git_Hub\vision\xml\face_detection_yunet_2023mar.onnx",'',(320, 320),0.9, 0.3, 5000)

# %%
h,w,_=img.shape
model.setInputSize((w, h))
res= model.detect(img)
print(res)
# Out:
# (1, array([[531.99005   , 212.75372   ,  53.034473  ,  65.405876  ,
#         551.067     , 234.32631   , 573.471     , 234.74286   ,
#         564.99506   , 247.41467   , 552.3245    , 258.14713   ,
#         571.68146   , 258.97668   ,   0.91792256],
#        [427.15445   , 141.58568   ,  56.306408  ,  73.594246  ,
#         437.90298   , 171.0175    , 463.83994   , 170.61331   ,
#         448.6349    , 185.66096   , 440.8094    , 194.23036   ,
#         462.7726    , 195.92183   ,   0.9167677 ],
#        [311.63025   , 277.50793   ,  55.643623  ,  74.33253   ,
#         328.5988    , 303.5805    , 354.94342   , 305.3222    ,
#         342.05768   , 319.4663    , 327.75806   , 330.55475   ,
#         350.24      , 332.32922   ,   0.91654533],
#        [203.71509   , 207.04855   ,  72.731766  ,  84.37497   ,
#         231.65771   , 236.74689   , 261.26886   , 238.48904   ,
#         248.91136   , 255.77568   , 229.48772   , 269.36124   ,
# ...

# %%
res[1]
# Out:
# array([[531.99005   , 212.75372   ,  53.034473  ,  65.405876  ,
#         551.067     , 234.32631   , 573.471     , 234.74286   ,
#         564.99506   , 247.41467   , 552.3245    , 258.14713   ,
#         571.68146   , 258.97668   ,   0.91792256],
#        [427.15445   , 141.58568   ,  56.306408  ,  73.594246  ,
#         437.90298   , 171.0175    , 463.83994   , 170.61331   ,
#         448.6349    , 185.66096   , 440.8094    , 194.23036   ,
#         462.7726    , 195.92183   ,   0.9167677 ],
#        [311.63025   , 277.50793   ,  55.643623  ,  74.33253   ,
#         328.5988    , 303.5805    , 354.94342   , 305.3222    ,
#         342.05768   , 319.4663    , 327.75806   , 330.55475   ,
#         350.24      , 332.32922   ,   0.91654533],
#        [203.71509   , 207.04855   ,  72.731766  ,  84.37497   ,
#         231.65771   , 236.74689   , 261.26886   , 238.48904   ,
#         248.91136   , 255.77568   , 229.48772   , 269.36124   ,
# ...

# %%
len(res[1])
# Out:
# 5

# %%
for i in res[1]:
    print(i)
# Out:
# [531.99005    212.75372     53.034473    65.405876   551.067
#  234.32631    573.471      234.74286    564.99506    247.41467
#  552.3245     258.14713    571.68146    258.97668      0.91792256]
# [427.15445   141.58568    56.306408   73.594246  437.90298   171.0175
#  463.83994   170.61331   448.6349    185.66096   440.8094    194.23036
#  462.7726    195.92183     0.9167677]
# [311.63025    277.50793     55.643623    74.33253    328.5988
#  303.5805     354.94342    305.3222     342.05768    319.4663
#  327.75806    330.55475    350.24       332.32922      0.91654533]
# [203.71509   207.04855    72.731766   84.37497   231.65771   236.74689
#  261.26886   238.48904   248.91136   255.77568   229.48772   269.36124
#  251.25233   269.02048     0.9059808]
# [178.9856     195.02971     16.625061    19.838919   184.22832
#  201.58348    191.75787    201.88509    188.3876     205.5965
#  185.02971    210.4022     191.25336    209.15189      0.90242636]

# %%
for i in res[1]:
    c=i[:-1]
    print(c)
# Out:
# [531.99005  212.75372   53.034473  65.405876 551.067    234.32631
#  573.471    234.74286  564.99506  247.41467  552.3245   258.14713
#  571.68146  258.97668 ]
# [427.15445  141.58568   56.306408  73.594246 437.90298  171.0175
#  463.83994  170.61331  448.6349   185.66096  440.8094   194.23036
#  462.7726   195.92183 ]
# [311.63025  277.50793   55.643623  74.33253  328.5988   303.5805
#  354.94342  305.3222   342.05768  319.4663   327.75806  330.55475
#  350.24     332.32922 ]
# [203.71509  207.04855   72.731766  84.37497  231.65771  236.74689
#  261.26886  238.48904  248.91136  255.77568  229.48772  269.36124
#  251.25233  269.02048 ]
# [178.9856   195.02971   16.625061  19.838919 184.22832  201.58348
#  191.75787  201.88509  188.3876   205.5965   185.02971  210.4022
#  191.25336  209.15189 ]

# %%
for i in res[1]:
    c=i[:-1].astype(np.int32)
    print(c)
# Out:
# [531 212  53  65 551 234 573 234 564 247 552 258 571 258]
# [427 141  56  73 437 171 463 170 448 185 440 194 462 195]
# [311 277  55  74 328 303 354 305 342 319 327 330 350 332]
# [203 207  72  84 231 236 261 238 248 255 229 269 251 269]
# [178 195  16  19 184 201 191 201 188 205 185 210 191 209]

# %%
for i in res[1]:
    c=i[:-1].astype(np.int32)
    cv2.rectangle(img,(c[0], c[1]), ((c[0]+c[2]),(c[1]+c[3])), (0, 255, 0), 4) # detect face

    
    cv2.imshow('faces', img)
    if cv2.waitKey(0) & 0xFF == ord('q'):
        break


cv2.destroyAllWindows()

# %%
for i in res[1]:
    c=i[:-1].astype(np.int32)
    cv2.rectangle(img,(c[0], c[1]), ((c[0]+c[2]),(c[1]+c[3])), (0, 255, 0), 4) # detect face
    cv2.circle(img, (c[4], c[5]), 4, (255, 255, 0), -1) # detect right eye
    cv2.circle(img, (c[6], c[7]), 4, (255, 255, 0), -1) # detect left eye
    cv2.circle(img, (c[8], c[9]), 4, (255, 255, 0), -1) # detect nose
    cv2.circle(img, (c[10], c[11]), 4, (0, 0, 255), -1) # detect right lip
    cv2.circle(img, (c[12], c[13]), 4, (0, 0, 255), -1) # detect left lip 
    
    cv2.imshow('faces', img)
    if cv2.waitKey(0) & 0xFF == ord('q'):
        break


cv2.destroyAllWindows()

# %%
# Example 1 with image 

import numpy as np
import matplotlib.pyplot as plt
import cv2

img= cv2.imread('../imgs/peops.jpg')
model=cv2.FaceDetectorYN_create(r"D:\Git_Hub\vision\xml\face_detection_yunet_2023mar.onnx",'',(320, 320),0.9, 0.3, 5000)
h,w,_=img.shape
model.setInputSize((w, h))
res= model.detect(img)
if res[1] is not None:
    print(f"Number of Face: {len(res[1])}")

if res[1] is not None:
    for i in res[1]:
        c=i[:-1].astype(np.int32)
        cv2.rectangle(img,(c[0], c[1]), ((c[0]+c[2]),(c[1]+c[3])), (0, 255, 0), 4) # detect face
        cv2.circle(img, (c[4], c[5]), 4, (255, 255, 0), -1) # detect right eye
        cv2.circle(img, (c[6], c[7]), 4, (255, 255, 0), -1) # detect left eye
        cv2.circle(img, (c[8], c[9]), 4, (255, 255, 0), -1) # detect nose
        cv2.circle(img, (c[10], c[11]), 4, (0, 0, 255), -1) # detect right lip
        cv2.circle(img, (c[12], c[13]), 4, (0, 0, 255), -1) # detect left lip 
    cv2.imshow('faces', img)
    cv2.imwrite("saved_image.jpg", img)

    cv2.waitKey(0)


cv2.destroyAllWindows()
# Out:
# Number of Face: 5

# %%
# Example 2 with camera

import numpy as np
import matplotlib.pyplot as plt
import cv2

cap= cv2.VideoCapture(1)
model=cv2.FaceDetectorYN_create(r"D:\Git_Hub\vision\xml\face_detection_yunet_2023mar.onnx",'',(320, 320),0.9, 0.3, 5000)

while True:
    ret,img= cap.read()
    h,w,_=img.shape
    model.setInputSize((w, h))
    res= model.detect(img)

    
    if res[1] is not None:
        for i in res[1]:
            c=i[:-1].astype(np.int32)
            cv2.rectangle(img,(c[0], c[1]), ((c[0]+c[2]),(c[1]+c[3])), (0, 255, 0), 4) # detect face
            cv2.circle(img, (c[4], c[5]), 4, (255, 255, 0), -1) # detect right eye
            cv2.circle(img, (c[6], c[7]), 4, (255, 255, 0), -1) # detect left eye
            cv2.circle(img, (c[8], c[9]), 4, (255, 255, 0), -1) # detect nose
            cv2.circle(img, (c[10], c[11]), 4, (0, 0, 255), -1) # detect right lip
            cv2.circle(img, (c[12], c[13]), 4, (0, 0, 255), -1) # detect left lip 
    cv2.imshow("camera", img)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
cap.release()
cv2.destroyAllWindows()

# %%
# Example 3 with camera and crop

import numpy as np
import matplotlib.pyplot as plt
import cv2

cap = cv2.VideoCapture(1)
model = cv2.FaceDetectorYN_create(r"D:\Git_Hub\vision\xml\face_detection_yunet_2023mar.onnx",'',(320, 320),0.9,0.3,5000)


while True:
    ret, frame = cap.read()
    h, w, _ = frame.shape
    model.setInputSize((w, h))
    res = model.detect(frame)
    if res[1] is not None:
        for i in res[1]:
            c = i[:-1].astype(np.int32)  # coordinate
            cv2.rectangle(frame,(c[0], c[1]),((c[0] + c[2]), (c[1] + c[3])),(0, 255, 0),4)  # detect face
            crop = frame[min(c[1], c[1] + c[3]): max(c[1], c[1] + c[3]),min(c[0], c[0] + c[2]): max(c[0], c[0] + c[2])]
    cv2.imshow('camera', frame)        
    if crop is not None:
        cv2.imshow('face', crop)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
